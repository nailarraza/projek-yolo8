# %% [markdown]
# <a href="https://colab.research.google.com/github/nailarraza/projek-yolo8/blob/main/notebooks/oil-image-mining.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Langkah 1: Instalasi library simple_image_download
# Jalankan perintah ini di sel Colab. Tanda seru (!) mengeksekusi perintah shell.
# !pip install simple_image_download

# Langkah 2: Impor library yang dibutuhkan
import os
import shutil # Untuk membuat file ZIP
from google.colab import files # Untuk mengunduh file dari Colab
from simple_image_download import simple_image_download as simp

# Membuat instance dari image downloader
image_downloader = simp.simple_image_download()

# Langkah 3: Tentukan kata kunci dan batasan jumlah gambar
# Daftar kata kunci yang akan dicari, diperbarui sesuai permintaan pengguna
keywords = [
    "oli motor",
    "motorcycle oil",
    "ganti oli motor",
    "motorcycle oil change",
    "oli motor bekas",
    "used motorcycle oil",
    "oli motor asli",
    "genuine motorcycle oil",
    "fake motorcycle oil",
    "warna oli motor",
    "oil motorcycle color",
    "oil motorcycle color genuine",
    "oil viscosity",
    "kekentalan oli",
    "oil motor bebek",
    "oil motor matic",
    "oil motor sport",
    "oil motor merk internesional",
    "oli motor merk indonesia",
    "oli motor merk amerika"
    "oli motor merk asia",
    "oli motor merk eropa"
]

# Batasan jumlah gambar yang ingin diunduh per kata kunci
limit_per_keyword = 25 # Sesuaikan jika perlu

# Nama folder utama tempat gambar disimpan (default oleh library adalah 'simple_images')
main_download_folder = "simple_images"
zip_file_name = "downloaded_motor_oil_images" # Nama untuk file ZIP (tanpa .zip)

# Pesan awal
print("Memulai proses pengunduhan gambar...\n")

# Langkah 4: Looping melalui setiap kata kunci dan mengunduh gambar
for keyword in keywords:
    print(f"--------------------------------------------------")
    print(f"Mencari dan mengunduh gambar untuk kata kunci: '{keyword}'")
    print(f"Target jumlah gambar: {limit_per_keyword}")
    print(f"--------------------------------------------------")

    try:
        # Memanggil fungsi download
        # Menghapus argumen 'download_path' karena tidak didukung oleh metode .download()
        # Library akan secara otomatis menyimpan ke folder 'simple_images/keyword_name/'
        image_downloader.download(keyword, limit_per_keyword)
        print(f"\nBerhasil mengunduh gambar untuk '{keyword}'.")
        # Library simple_image_download biasanya sudah membuat subfolder dengan nama keyword.
        # Path lengkapnya: main_download_folder/keyword_folder_name/
        # Mengganti spasi dengan garis bawah untuk referensi nama folder jika diperlukan,
        # meskipun library mungkin menangani ini secara internal.
        keyword_folder_name = keyword.replace(' ', '_')
        print(f"Gambar disimpan di folder: {main_download_folder}/{keyword_folder_name}/ (atau nama folder serupa yang dibuat library)")
    except Exception as e:
        print(f"Terjadi kesalahan saat mengunduh gambar untuk '{keyword}': {e}")
        print(f"Melanjutkan ke kata kunci berikutnya...")

    print("\n")

print("==================================================")
print("Proses pengunduhan semua gambar telah selesai.")
print("==================================================")

# Langkah 5: Mengemas folder gambar menjadi file ZIP
print(f"\nMengemas folder '{main_download_folder}' menjadi file ZIP...")
if os.path.exists(main_download_folder) and os.listdir(main_download_folder):
    try:
        shutil.make_archive(zip_file_name, 'zip', main_download_folder)
        print(f"Berhasil membuat file ZIP: {zip_file_name}.zip")

        # Langkah 6: Mengunduh file ZIP
        print(f"\nMempersiapkan unduhan untuk file {zip_file_name}.zip...")
        print("Harap tunggu, proses unduhan akan dimulai secara otomatis oleh browser Anda.")
        files.download(f"{zip_file_name}.zip")
        print(f"\nJika unduhan tidak dimulai, periksa pengaturan pop-up browser Anda.")
    except Exception as e:
        print(f"Terjadi kesalahan saat membuat atau mengunduh file ZIP: {e}")
else:
    print(f"Folder '{main_download_folder}' tidak ditemukan atau kosong. Tidak ada yang di-ZIP.")

print("\n==================================================")
print("Semua proses telah selesai.")
print("==================================================")


# Catatan:
# 1. Gambar akan diunduh ke folder bernama 'simple_images' (atau nama folder yang didefinisikan di main_download_folder).
#    Di dalam folder tersebut, akan ada subfolder untuk setiap kata kunci yang dibuat secara otomatis oleh library.
# 2. Setelah semua gambar diunduh, skrip akan mencoba membuat file ZIP bernama 'downloaded_motor_oil_images.zip'.
# 3. Kemudian, skrip akan secara otomatis memicu unduhan file ZIP tersebut ke komputer lokal Anda.
#    Proses ini menggunakan fitur `google.colab.files.download`.
# 4. Pastikan browser Anda mengizinkan pop-up dari Google Colab agar unduhan dapat dimulai.
# 5. Jika Anda menjalankan kode ini lagi, library simple_image_download mungkin akan melewatkan gambar yang sudah ada.
#    Folder ZIP yang lama (jika ada di environment Colab) akan ditimpa saat shutil.make_archive dijalankan lagi.
# Out:
# Requirement already satisfied: simple_image_download in /usr/local/lib/python3.11/dist-packages (0.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from simple_image_download) (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->simple_image_download) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->simple_image_download) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->simple_image_download) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->simple_image_download) (2025.4.26)
# Memulai proses pengunduhan gambar...
#
# --------------------------------------------------
# Mencari dan mengunduh gambar untuk kata kunci: 'oli motor'
# Target jumlah gambar: 25
# --------------------------------------------------
#
# Berhasil mengunduh gambar untuk 'oli motor'.
# Gambar disimpan di folder: simple_images/oli_motor/ (atau nama folder serupa yang dibuat library)
#
#
# --------------------------------------------------
# Mencari dan mengunduh gambar untuk kata kunci: 'motorcycle oil'
# Target jumlah gambar: 25
# --------------------------------------------------
#
# Berhasil mengunduh gambar untuk 'motorcycle oil'.
# Gambar disimpan di folder: simple_images/motorcycle_oil/ (atau nama folder serupa yang dibuat library)
#
#
# --------------------------------------------------
# Mencari dan mengunduh gambar untuk kata kunci: 'ganti oli motor'
# Target jumlah gambar: 25
# --------------------------------------------------
# HTTPSConnectionPool(host='automotive.evalube.com', port=443): Max retries exceeded with url: /wp-content/uploads/2019/12/oli-matic.jpg (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x78e72047ee90>, 'Connection to automotive.evalube.com timed out. (connect timeout=None)'))
# HTTPSConnectionPool(host='automotive.evalube.com', port=443): Max retries exceeded with url: /wp-content/uploads/2020/09/3-Kesalahan-yang-Sering-Dilakukan-Saat-Mengganti-Oli.jpg (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x78e7203f1590>, 'Connection to automotive.evalube.com timed out. (connect timeout=None)'))
#
# Berhasil mengunduh gambar untuk 'ganti oli motor'.
# Gambar disimpan di folder: simple_images/ganti_oli_motor/ (atau nama folder serupa yang dibuat library)
#
#
# --------------------------------------------------
# Mencari dan mengunduh gambar untuk kata kunci: 'motorcycle oil change'
# Target jumlah gambar: 25
# --------------------------------------------------
#
# Berhasil mengunduh gambar untuk 'motorcycle oil change'.
# Gambar disimpan di folder: simple_images/motorcycle_oil_change/ (atau nama folder serupa yang dibuat library)
#
#
# --------------------------------------------------
# Mencari dan mengunduh gambar untuk kata kunci: 'oli motor bekas'
# Target jumlah gambar: 25
# --------------------------------------------------
#
# Berhasil mengunduh gambar untuk 'oli motor bekas'.
# Gambar disimpan di folder: simple_images/oli_motor_bekas/ (atau nama folder serupa yang dibuat library)
#
#
# --------------------------------------------------
# Mencari dan mengunduh gambar untuk kata kunci: 'used motorcycle oil'
# Target jumlah gambar: 25
# --------------------------------------------------
#
# Berhasil mengunduh gambar untuk 'used motorcycle oil'.
# Gambar disimpan di folder: simple_images/used_motorcycle_oil/ (atau nama folder serupa yang dibuat library)
#
#
# --------------------------------------------------
# Mencari dan mengunduh gambar untuk kata kunci: 'oli motor asli'
# Target jumlah gambar: 25
# --------------------------------------------------
#
# Berhasil mengunduh gambar untuk 'oli motor asli'.
# Gambar disimpan di folder: simple_images/oli_motor_asli/ (atau nama folder serupa yang dibuat library)
#
#
# --------------------------------------------------
# Mencari dan mengunduh gambar untuk kata kunci: 'genuine motorcycle oil'
# Target jumlah gambar: 25
# --------------------------------------------------
#
# Berhasil mengunduh gambar untuk 'genuine motorcycle oil'.
# Gambar disimpan di folder: simple_images/genuine_motorcycle_oil/ (atau nama folder serupa yang dibuat library)
#
#
# --------------------------------------------------
# Mencari dan mengunduh gambar untuk kata kunci: 'fake motorcycle oil'
# Target jumlah gambar: 25
# --------------------------------------------------
#
# Berhasil mengunduh gambar untuk 'fake motorcycle oil'.
# Gambar disimpan di folder: simple_images/fake_motorcycle_oil/ (atau nama folder serupa yang dibuat library)
#
#
# --------------------------------------------------
# Mencari dan mengunduh gambar untuk kata kunci: 'warna oli motor'
# Target jumlah gambar: 25
# --------------------------------------------------
#
# Berhasil mengunduh gambar untuk 'warna oli motor'.
# Gambar disimpan di folder: simple_images/warna_oli_motor/ (atau nama folder serupa yang dibuat library)
#
#
# --------------------------------------------------
# Mencari dan mengunduh gambar untuk kata kunci: 'oil motorcycle color'
# Target jumlah gambar: 25
# --------------------------------------------------
#
# Berhasil mengunduh gambar untuk 'oil motorcycle color'.
# Gambar disimpan di folder: simple_images/oil_motorcycle_color/ (atau nama folder serupa yang dibuat library)
#
#
# --------------------------------------------------
# Mencari dan mengunduh gambar untuk kata kunci: 'oil motorcycle color genuine'
# Target jumlah gambar: 25
# --------------------------------------------------
#
# Berhasil mengunduh gambar untuk 'oil motorcycle color genuine'.
# Gambar disimpan di folder: simple_images/oil_motorcycle_color_genuine/ (atau nama folder serupa yang dibuat library)
#
#
# --------------------------------------------------
# Mencari dan mengunduh gambar untuk kata kunci: 'oil viscosity'
# Target jumlah gambar: 25
# --------------------------------------------------
# HTTPSConnectionPool(host='media.noria.com', port=443): Max retries exceeded with url: /sites/archive_images/backup_200211_viscosity-tab1-2.gif (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1016)')))
# HTTPSConnectionPool(host='media.noria.com', port=443): Max retries exceeded with url: /sites/Uploads/2021/1/5/02_Viscosity-Image1_650w.jpg (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1016)')))
#
# Berhasil mengunduh gambar untuk 'oil viscosity'.
# Gambar disimpan di folder: simple_images/oil_viscosity/ (atau nama folder serupa yang dibuat library)
#
#
# --------------------------------------------------
# Mencari dan mengunduh gambar untuk kata kunci: 'kekentalan oli'
# Target jumlah gambar: 25
# --------------------------------------------------
# HTTPSConnectionPool(host='automotive.evalube.com', port=443): Max retries exceeded with url: /wp-content/uploads/2019/07/olievalube.jpg (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x78e7380e5f10>, 'Connection to automotive.evalube.com timed out. (connect timeout=None)'))
#
# Berhasil mengunduh gambar untuk 'kekentalan oli'.
# Gambar disimpan di folder: simple_images/kekentalan_oli/ (atau nama folder serupa yang dibuat library)
#
#
# --------------------------------------------------
# Mencari dan mengunduh gambar untuk kata kunci: 'oil motor bebek'
# Target jumlah gambar: 25
# --------------------------------------------------
#
# Berhasil mengunduh gambar untuk 'oil motor bebek'.
# Gambar disimpan di folder: simple_images/oil_motor_bebek/ (atau nama folder serupa yang dibuat library)
#
#
# --------------------------------------------------
# Mencari dan mengunduh gambar untuk kata kunci: 'oil motor matic'
# Target jumlah gambar: 25
# --------------------------------------------------
# ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
#
# Berhasil mengunduh gambar untuk 'oil motor matic'.
# Gambar disimpan di folder: simple_images/oil_motor_matic/ (atau nama folder serupa yang dibuat library)
#
#
# --------------------------------------------------
# Mencari dan mengunduh gambar untuk kata kunci: 'oil motor sport'
# Target jumlah gambar: 25
# --------------------------------------------------
#
# Berhasil mengunduh gambar untuk 'oil motor sport'.
# Gambar disimpan di folder: simple_images/oil_motor_sport/ (atau nama folder serupa yang dibuat library)
#
#
# --------------------------------------------------
# Mencari dan mengunduh gambar untuk kata kunci: 'oil motor merk internesional'
# Target jumlah gambar: 25
# --------------------------------------------------
#
# Berhasil mengunduh gambar untuk 'oil motor merk internesional'.
# Gambar disimpan di folder: simple_images/oil_motor_merk_internesional/ (atau nama folder serupa yang dibuat library)
#
#
# --------------------------------------------------
# Mencari dan mengunduh gambar untuk kata kunci: 'oli motor merk indonesia'
# Target jumlah gambar: 25
# --------------------------------------------------
#
# Berhasil mengunduh gambar untuk 'oli motor merk indonesia'.
# Gambar disimpan di folder: simple_images/oli_motor_merk_indonesia/ (atau nama folder serupa yang dibuat library)
#
#
# --------------------------------------------------
# Mencari dan mengunduh gambar untuk kata kunci: 'oli motor merk amerikaoli motor merk asia'
# Target jumlah gambar: 25
# --------------------------------------------------
# HTTPSConnectionPool(host='automotive.evalube.com', port=443): Max retries exceeded with url: /wp-content/uploads/2018/05/artikel-02.jpg (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x78e720478090>, 'Connection to automotive.evalube.com timed out. (connect timeout=None)'))
#
# Berhasil mengunduh gambar untuk 'oli motor merk amerikaoli motor merk asia'.
# Gambar disimpan di folder: simple_images/oli_motor_merk_amerikaoli_motor_merk_asia/ (atau nama folder serupa yang dibuat library)
#
#
# --------------------------------------------------
# Mencari dan mengunduh gambar untuk kata kunci: 'oli motor merk eropa'
# Target jumlah gambar: 25
# --------------------------------------------------
# HTTPSConnectionPool(host='automotive.evalube.com', port=443): Max retries exceeded with url: /wp-content/uploads/2018/05/artikel-02.jpg (Caused by ConnectTimeoutError(<urllib3.connection.HTTPSConnection object at 0x78e72046e0d0>, 'Connection to automotive.evalube.com timed out. (connect timeout=None)'))
#
# Berhasil mengunduh gambar untuk 'oli motor merk eropa'.
# Gambar disimpan di folder: simple_images/oli_motor_merk_eropa/ (atau nama folder serupa yang dibuat library)
#
#
# ==================================================
# Proses pengunduhan semua gambar telah selesai.
# ==================================================
#
# Mengemas folder 'simple_images' menjadi file ZIP...
# Berhasil membuat file ZIP: downloaded_motor_oil_images.zip
#
# Mempersiapkan unduhan untuk file downloaded_motor_oil_images.zip...
# Harap tunggu, proses unduhan akan dimulai secara otomatis oleh browser Anda.
# Jika unduhan tidak dimulai, periksa pengaturan pop-up browser Anda.
#
# ==================================================
# Semua proses telah selesai.
# ==================================================
